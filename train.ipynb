# %%
print('f')
# Out:
# f

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# Unzip images to a custom data folder
# !unzip -q C:\Users\HP\OneDrive\Desktop\yolo-helmet\data.zip -d /content/custom_data
# Out:
# unzip:  cannot find or open C:UsersHPOneDriveDesktopyolo-helmetdata.zip, C:UsersHPOneDriveDesktopyolo-helmetdata.zip.zip or C:UsersHPOneDriveDesktopyolo-helmetdata.zip.ZIP.
